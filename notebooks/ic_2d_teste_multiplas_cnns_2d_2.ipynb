# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
from scipy import ndimage
import cv2
from gc import collect
import random
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn
import cv2
from sklearn.utils import shuffle

# %%
def get_labels(label_file):
    """lê a tabela com as informações dos pacientes e retorna uma matriz com o ID e as labels"""
    labels = pd.read_csv(label_file)
    cancer_labels = dict()

    for p in labels.index:
        cancer_labels[labels['PatientID'][p]] = [int(labels['Normal'][p]), int(labels['Actionable'][p]), int(labels['Benign'][p]), int(labels['Cancer'][p])]

    return cancer_labels

# %%
def read_dataset(features_pathfile, csv_labels_pathfile, images_per_class):
  """
      A partir de um conjunto de numpy arrays salvos e do csv com as 
  labels, será montado o conjunto de dados para uso nos algoritmos com um 
  número máximo de features por classe. 
  ********(função com possível modificação no futuro)********
  """
  examples_per_class = [0, 0, 0, 0]

  pacients_ID = os.listdir(features_pathfile)
  labels_list = get_labels(csv_labels_pathfile)
  X, y = [], []
  for ID in pacients_ID:
    try:
        label = labels_list[ID[:-4]]
    except:
        continue
    if images_per_class != -1:
        if examples_per_class[np.argmax(label)] > images_per_class:
            continue

        examples_per_class[np.argmax(label)] += 1
        X.append(np.load(features_pathfile + '/' + ID))

        if len(y) == images_per_class*4:
            break
    else:
        X.append(np.load(features_pathfile + '/' + ID))

    y.append(label)

  return np.array(X), np.array(y)

# %%
def data_augmentation(X, y):
    new_images = []
    new_labels = []
    for x, label in zip(X, y):
        x = np.squeeze(x, -1)
        new_images.append(np.expand_dims(x, -1).astype('float16'))
        
        new_images.append(ndimage.rotate(np.expand_dims(x, -1).astype('float32'), angle=10, axes=(1, 0), reshape=False).astype('float16'))
        new_images.append(ndimage.rotate(np.expand_dims(x, -1).astype('float32'), angle=-10, axes=(1, 0), reshape=False).astype('float16'))
        
        x = cv2.flip(x, 1)
        new_images.append(np.expand_dims(x, -1).astype('float16'))
        new_images.append(ndimage.rotate(np.expand_dims(x, -1).astype('float32'), angle=10, axes=(1, 0), reshape=False).astype('float16'))
        new_images.append(ndimage.rotate(np.expand_dims(x, -1).astype('float32'), angle=-10, axes=(1, 0), reshape=False).astype('float16'))
        
        for _ in range(6):
            new_labels.append(label)
        
    return np.array(new_images), np.array(new_labels)

# %%
def separate_slices(img):
  slices = []

  for i in range(img.shape[-2]):
    slices.append(img[:,:,i])
  
  slices.append(np.mean(img, axis=-2))

  return slices

# %%
X, y = read_dataset('/content/drive/MyDrive/zap/240x320x10', '/content/drive/MyDrive/zap/arrays_gigantes/labels.csv', -1)


dataset_length = len(X)

X, y = shuffle(X, y, random_state=437843)

X_train, y_train = X[0:int(dataset_length*0.6)], y[0:int(dataset_length*0.6)]
X_val, y_val = X[int(dataset_length*0.6):int(dataset_length*0.8)], y[int(dataset_length*0.6):int(dataset_length*0.8)]
X_test, y_test = X[int(dataset_length*0.8):], y[int(dataset_length*0.8):]

# %%
X_train, y_train = data_augmentation(X_train, y_train)

# %%
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 1

# %%
#callback para salvar o modelo posteriormente
checkpoint_callback_accuracy = tf.keras.callbacks.ModelCheckpoint(filepath='./models/accuracy/',
                                                                  save_weights_only=True,
                                                                  monitor='val_categorical_accuracy',
                                                                  mode='max',
                                                                  save_best_only=True)

checkpoint_callback_precision = tf.keras.callbacks.ModelCheckpoint(filepath='./models/precision/',
                                                                   save_weights_only=True,
                                                                   monitor='val_precision',
                                                                   mode='max',
                                                                   save_best_only=True)

checkpoint_callback_auc1 = tf.keras.callbacks.ModelCheckpoint(filepath='./models/auc1/',
                                                             save_weights_only=True,
                                                             monitor='val_auc',
                                                             mode='max',
                                                             save_best_only=True)

checkpoint_callback_auc2 = tf.keras.callbacks.ModelCheckpoint(filepath='./models/auc2/',
                                                             save_weights_only=True,
                                                             monitor='val_auc_1',
                                                             mode='max',
                                                             save_best_only=True)

checkpoint_loss = tf.keras.callbacks.ModelCheckpoint(filepath='.models/models/loss/',
                                                     save_weights_only=True,
                                                     monitor='val_loss',
                                                     mode='min',
                                                     save_best_only=True)

# %%
class multi_VGG(tf.keras.Model):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        
        self.hiddens1 = [tf.keras.layers.Conv2D(input_shape=(240, 320, 1), filters=64, kernel_size=(6,8), use_bias=True, 
                                                 padding='same', activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True,padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu",kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(3, 4))]
        
        self.hiddens2 = [tf.keras.layers.Conv2D(input_shape=(240, 320, 1), filters=64, kernel_size=(6,8), use_bias=True, 
                                                 padding='same', activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True,padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu",kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(3, 4))]
        
        self.hiddens3 = [tf.keras.layers.Conv2D(input_shape=(240, 320, 1), filters=64, kernel_size=(6,8), use_bias=True, 
                                                 padding='same', activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True,padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu",kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(3, 4))]
        
        self.hiddens4 = [tf.keras.layers.Conv2D(input_shape=(240, 320, 1), filters=64, kernel_size=(6,8), use_bias=True, 
                                                 padding='same', activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True,padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu",kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(3, 4))]
        
        self.hiddens5 = [tf.keras.layers.Conv2D(input_shape=(240, 320, 1), filters=64, kernel_size=(6,8), use_bias=True, 
                                                 padding='same', activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True,padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu",kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(3, 4))]
        
        self.hiddens6 = [tf.keras.layers.Conv2D(input_shape=(240, 320, 1), filters=64, kernel_size=(6,8), use_bias=True, 
                                                 padding='same', activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True,padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu",kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(3, 4))]
        
        self.hiddens7 = [tf.keras.layers.Conv2D(input_shape=(240, 320, 1), filters=64, kernel_size=(6,8), use_bias=True, 
                                                 padding='same', activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True,padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu",kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(3, 4))]
        
        self.hiddens8 = [tf.keras.layers.Conv2D(input_shape=(240, 320, 1), filters=64, kernel_size=(6,8), use_bias=True, 
                                                 padding='same', activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True,padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu",kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(3, 4))]
        
        self.hiddens9 = [tf.keras.layers.Conv2D(input_shape=(240, 320, 1), filters=64, kernel_size=(6,8), use_bias=True, 
                                                 padding='same', activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True,padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu",kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(3, 4))]
        
        self.hiddens10 = [tf.keras.layers.Conv2D(input_shape=(240, 320, 1), filters=64, kernel_size=(6,8), use_bias=True, 
                                                 padding='same', activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True,padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu",kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                             
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', strides=2, 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 4), use_bias=True, padding='same', 
                                                    activation="relu", kernel_initializer=tf.keras.initializers.HeNormal()),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.MaxPool2D(pool_size=(3, 4))]
        
        self.dense_layers = [tf.keras.layers.Flatten(),
                             tf.keras.layers.Dense(units=4096, activation='selu', kernel_initializer='lecun_normal'),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Dropout(0.5),
                             tf.keras.layers.Dense(units=4096, activation='selu', kernel_initializer='lecun_normal'),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Dropout(0.5),
                             tf.keras.layers.Dense(units=4, activation='softmax')]
        
    def call(self, inputs):
        input1 = tf.convert_to_tensor(inputs[:,:,:,0,0:])
        input2 = tf.convert_to_tensor(inputs[:,:,:,1,0:])
        input3 = tf.convert_to_tensor(inputs[:,:,:,2,0:])
        input4 = tf.convert_to_tensor(inputs[:,:,:,3,0:])
        input5 = tf.convert_to_tensor(inputs[:,:,:,4,0:])
        input6 = tf.convert_to_tensor(inputs[:,:,:,5,0:])
        input7 = tf.convert_to_tensor(inputs[:,:,:,6,0:])
        input8 = tf.convert_to_tensor(inputs[:,:,:,7,0:])
        input9 = tf.convert_to_tensor(inputs[:,:,:,8,0:])
        input10 = tf.convert_to_tensor(inputs[:,:,:,9,0:])
        
        output1 = self.hiddens1[0](input1)
        for layer in self.hiddens1[1:]:
            output1 = layer(output1)
            
        output2 = self.hiddens2[0](input2)
        for layer in self.hiddens2[1:]:
            output2 = layer(output2)        
            
        output3 = self.hiddens3[0](input3)
        for layer in self.hiddens3[1:]:
            output3 = layer(output3) 
            
        output4 = self.hiddens4[0](input4)
        for layer in self.hiddens4[1:]:
            output4 = layer(output4)
        
        output5 = self.hiddens5[0](input5)
        for layer in self.hiddens5[1:]:
            output5 = layer(output5) 
        
        output6 = self.hiddens6[0](input6)
        for layer in self.hiddens6[1:]:
            output6 = layer(output6) 
        
        output7 = self.hiddens7[0](input7)
        for layer in self.hiddens7[1:]:
            output7 = layer(output7) 
        
        output8 = self.hiddens8[0](input8)
        for layer in self.hiddens8[1:]:
            output8 = layer(output8) 
        
        output9 = self.hiddens9[0](input9)
        for layer in self.hiddens9[1:]:
            output9 = layer(output9) 
            
        output10 = self.hiddens10[0](input10)
        for layer in self.hiddens10[1:]:
            output10 = layer(output10) 
            
        concat = tf.keras.layers.concatenate([output1, output2, output3, output4, output5, output6, output7, output8, output9, output10])
        
        output = self.dense_layers[0](concat)
        for layer in self.dense_layers[1:]:
            output = layer(output)
            
        return output

# %%
multi_VGG_test = multi_VGG()

# %%
multi_VGG_test.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0015), 
                    loss='categorical_crossentropy', 
                    metrics=[tf.keras.metrics.CategoricalAccuracy(), 
                             tf.keras.metrics.Precision(),
                             tf.keras.metrics.AUC(multi_label=True, num_labels=4, label_weights=[1/0.3381294964028777, 1/0.2517985611510791, 1/0.2302158273381295, 1/0.17985611510791366]),
                             tf.keras.metrics.AUC(multi_label=True, num_labels=4)])

multi_VGG_test.fit(X_train,
                y_train,
                batch_size=8,
                epochs=50,
                shuffle=True,
                validation_data=(X_val, y_val),
                callbacks=[checkpoint_callback_accuracy, 
                           checkpoint_callback_precision, 
                           checkpoint_callback_auc1, 
                           checkpoint_callback_auc2,
                           checkpoint_loss],
                workers=1,
                use_multiprocessing=True)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 238s 1s/step - loss: 4.0822 - categorical_accuracy: 0.2920 - precision: 0.2857 - auc: 0.5232 - auc_1: 0.5229 - val_loss: 192.9502 - val_categorical_accuracy: 0.2727 - val_precision: 0.2727 - val_auc: 0.5941 - val_auc_1: 0.5781
# Epoch 2/50
# 100/100 [==============================] - 53s 531ms/step - loss: 3.0370 - categorical_accuracy: 0.3020 - precision: 0.3053 - auc: 0.5360 - auc_1: 0.5329 - val_loss: 8.2246 - val_categorical_accuracy: 0.0682 - val_precision: 0.0682 - val_auc: 0.3922 - val_auc_1: 0.4084
# Epoch 3/50
# 100/100 [==============================] - 114s 1s/step - loss: 2.9945 - categorical_accuracy: 0.2544 - precision: 0.2572 - auc: 0.5169 - auc_1: 0.5139 - val_loss: 1.4699 - val_categorical_accuracy: 0.2955 - val_precision: 0.5556 - val_auc: 0.6191 - val_auc_1: 0.6089
# Epoch 4/50
# 100/100 [==============================] - 38s 377ms/step - loss: 2.7303 - categorical_accuracy: 0.3221 - precision: 0.3290 - auc: 0.5689 - auc_1: 0.5594 - val_loss: 3.8086 - val_categorical_accuracy: 0.2955 - val_precision: 0.2955 - val_auc: 0.4603 - val_auc_1: 0.4634
# Epoch 5/50
# 100/100 [==============================] - 37s 368ms/step - loss: 3.1214 - categorical_accuracy: 0.2832 - precision: 0.2890 - auc: 0.5293 - auc_1: 0.5236 - val_loss: 2.0135 - val_categorical_accuracy: 0.2045 - val_precision: 0.2121 - val_auc: 0.4473 - val_auc_1: 0.4461
# Epoch 6/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.8124 - categorical_accuracy: 0.2870 - precision: 0.2870 - auc: 0.5443 - auc_1: 0.5359 - val_loss: 2.7755 - val_categorical_accuracy: 0.2273 - val_precision: 0.2121 - val_auc: 0.3967 - val_auc_1: 0.3966
# Epoch 7/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.8033 - categorical_accuracy: 0.3008 - precision: 0.3050 - auc: 0.5563 - auc_1: 0.5493 - val_loss: 2.9060 - val_categorical_accuracy: 0.2273 - val_precision: 0.1892 - val_auc: 0.4514 - val_auc_1: 0.4693
# Epoch 8/50
# 100/100 [==============================] - 49s 493ms/step - loss: 2.4498 - categorical_accuracy: 0.3647 - precision: 0.3729 - auc: 0.6037 - auc_1: 0.5964 - val_loss: 4.8232 - val_categorical_accuracy: 0.3636 - val_precision: 0.3721 - val_auc: 0.4996 - val_auc_1: 0.5305
# Epoch 9/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.8741 - categorical_accuracy: 0.3045 - precision: 0.3175 - auc: 0.5587 - auc_1: 0.5524 - val_loss: 2.3828 - val_categorical_accuracy: 0.1364 - val_precision: 0.1081 - val_auc: 0.3367 - val_auc_1: 0.3417
# Epoch 10/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.5782 - categorical_accuracy: 0.3358 - precision: 0.3333 - auc: 0.5731 - auc_1: 0.5612 - val_loss: 1.9620 - val_categorical_accuracy: 0.3409 - val_precision: 0.3438 - val_auc: 0.4196 - val_auc_1: 0.4433
# Epoch 11/50
# 100/100 [==============================] - 37s 368ms/step - loss: 3.1653 - categorical_accuracy: 0.3195 - precision: 0.3297 - auc: 0.5730 - auc_1: 0.5647 - val_loss: 451.3941 - val_categorical_accuracy: 0.3182 - val_precision: 0.3182 - val_auc: 0.5000 - val_auc_1: 0.5000
# Epoch 12/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.8320 - categorical_accuracy: 0.3308 - precision: 0.3338 - auc: 0.5598 - auc_1: 0.5543 - val_loss: 11.9457 - val_categorical_accuracy: 0.2955 - val_precision: 0.2955 - val_auc: 0.4545 - val_auc_1: 0.4463
# Epoch 13/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.8851 - categorical_accuracy: 0.2845 - precision: 0.2775 - auc: 0.5478 - auc_1: 0.5412 - val_loss: 22.0516 - val_categorical_accuracy: 0.3182 - val_precision: 0.3182 - val_auc: 0.4735 - val_auc_1: 0.4734
# Epoch 14/50
# 100/100 [==============================] - 37s 368ms/step - loss: 3.0772 - categorical_accuracy: 0.3058 - precision: 0.3005 - auc: 0.5745 - auc_1: 0.5657 - val_loss: 8.3127 - val_categorical_accuracy: 0.2045 - val_precision: 0.2045 - val_auc: 0.5034 - val_auc_1: 0.5056
# Epoch 15/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.6083 - categorical_accuracy: 0.3509 - precision: 0.3556 - auc: 0.5776 - auc_1: 0.5728 - val_loss: 5.8022 - val_categorical_accuracy: 0.2500 - val_precision: 0.2619 - val_auc: 0.4883 - val_auc_1: 0.5002
# Epoch 16/50
# 100/100 [==============================] - 37s 368ms/step - loss: 3.0117 - categorical_accuracy: 0.3559 - precision: 0.3528 - auc: 0.6091 - auc_1: 0.5973 - val_loss: 6.4293 - val_categorical_accuracy: 0.3182 - val_precision: 0.3000 - val_auc: 0.4148 - val_auc_1: 0.4356
# Epoch 17/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.7889 - categorical_accuracy: 0.3221 - precision: 0.3286 - auc: 0.5781 - auc_1: 0.5721 - val_loss: 3.3585 - val_categorical_accuracy: 0.2273 - val_precision: 0.2188 - val_auc: 0.5341 - val_auc_1: 0.5276
# Epoch 18/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.6163 - categorical_accuracy: 0.3571 - precision: 0.3697 - auc: 0.5894 - auc_1: 0.5837 - val_loss: 2.7110 - val_categorical_accuracy: 0.2500 - val_precision: 0.2381 - val_auc: 0.4235 - val_auc_1: 0.4481
# Epoch 19/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.5522 - categorical_accuracy: 0.3509 - precision: 0.3496 - auc: 0.6076 - auc_1: 0.5938 - val_loss: 5.6804 - val_categorical_accuracy: 0.2273 - val_precision: 0.2250 - val_auc: 0.4407 - val_auc_1: 0.4659
# Epoch 20/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.6094 - categorical_accuracy: 0.3534 - precision: 0.3564 - auc: 0.6198 - auc_1: 0.6070 - val_loss: 7.1482 - val_categorical_accuracy: 0.2727 - val_precision: 0.2791 - val_auc: 0.4660 - val_auc_1: 0.4679
# Epoch 21/50
# 100/100 [==============================] - 37s 369ms/step - loss: 2.7820 - categorical_accuracy: 0.3559 - precision: 0.3634 - auc: 0.6290 - auc_1: 0.6178 - val_loss: 5.1273 - val_categorical_accuracy: 0.1818 - val_precision: 0.1860 - val_auc: 0.4571 - val_auc_1: 0.4437
# Epoch 22/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.9040 - categorical_accuracy: 0.3559 - precision: 0.3572 - auc: 0.6158 - auc_1: 0.6043 - val_loss: 10.2315 - val_categorical_accuracy: 0.2955 - val_precision: 0.2955 - val_auc: 0.4689 - val_auc_1: 0.4612
# Epoch 23/50
# 100/100 [==============================] - 37s 369ms/step - loss: 2.5863 - categorical_accuracy: 0.3985 - precision: 0.4040 - auc: 0.6372 - auc_1: 0.6245 - val_loss: 6.1621 - val_categorical_accuracy: 0.2500 - val_precision: 0.2500 - val_auc: 0.4498 - val_auc_1: 0.4527
# Epoch 24/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.5962 - categorical_accuracy: 0.3371 - precision: 0.3524 - auc: 0.6396 - auc_1: 0.6243 - val_loss: 9.7455 - val_categorical_accuracy: 0.2500 - val_precision: 0.2500 - val_auc: 0.4620 - val_auc_1: 0.4662
# Epoch 25/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.7939 - categorical_accuracy: 0.3672 - precision: 0.3703 - auc: 0.6246 - auc_1: 0.6110 - val_loss: 6.4977 - val_categorical_accuracy: 0.2045 - val_precision: 0.2045 - val_auc: 0.4504 - val_auc_1: 0.4685
# Epoch 26/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.8269 - categorical_accuracy: 0.3659 - precision: 0.3745 - auc: 0.6302 - auc_1: 0.6164 - val_loss: 38.7972 - val_categorical_accuracy: 0.2500 - val_precision: 0.2500 - val_auc: 0.5866 - val_auc_1: 0.5681
# Epoch 27/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.5189 - categorical_accuracy: 0.3822 - precision: 0.3972 - auc: 0.6411 - auc_1: 0.6337 - val_loss: 7.1017 - val_categorical_accuracy: 0.2273 - val_precision: 0.2326 - val_auc: 0.5108 - val_auc_1: 0.5149
# Epoch 28/50
# 100/100 [==============================] - 37s 367ms/step - loss: 2.8213 - categorical_accuracy: 0.3684 - precision: 0.3671 - auc: 0.6256 - auc_1: 0.6155 - val_loss: 12.2159 - val_categorical_accuracy: 0.3409 - val_precision: 0.3488 - val_auc: 0.4875 - val_auc_1: 0.4871
# Epoch 29/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.9289 - categorical_accuracy: 0.3571 - precision: 0.3613 - auc: 0.6320 - auc_1: 0.6137 - val_loss: 1957.9094 - val_categorical_accuracy: 0.2955 - val_precision: 0.2955 - val_auc: 0.5000 - val_auc_1: 0.5000
# Epoch 30/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.5595 - categorical_accuracy: 0.3810 - precision: 0.3920 - auc: 0.6705 - auc_1: 0.6521 - val_loss: 22.6309 - val_categorical_accuracy: 0.2045 - val_precision: 0.2093 - val_auc: 0.3979 - val_auc_1: 0.4027
# Epoch 31/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.5675 - categorical_accuracy: 0.4298 - precision: 0.4368 - auc: 0.6884 - auc_1: 0.6711 - val_loss: 17.4987 - val_categorical_accuracy: 0.2727 - val_precision: 0.2727 - val_auc: 0.4863 - val_auc_1: 0.4963
# Epoch 32/50
# 100/100 [==============================] - 49s 488ms/step - loss: 2.1889 - categorical_accuracy: 0.4774 - precision: 0.4917 - auc: 0.7280 - auc_1: 0.7128 - val_loss: 2.3645 - val_categorical_accuracy: 0.4091 - val_precision: 0.3947 - val_auc: 0.5075 - val_auc_1: 0.5126
# Epoch 33/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.3715 - categorical_accuracy: 0.4524 - precision: 0.4644 - auc: 0.6943 - auc_1: 0.6818 - val_loss: 2.9977 - val_categorical_accuracy: 0.2955 - val_precision: 0.3077 - val_auc: 0.5390 - val_auc_1: 0.5394
# Epoch 34/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.3801 - categorical_accuracy: 0.4323 - precision: 0.4402 - auc: 0.6859 - auc_1: 0.6699 - val_loss: 4.0196 - val_categorical_accuracy: 0.2273 - val_precision: 0.2439 - val_auc: 0.3838 - val_auc_1: 0.4034
# Epoch 35/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.3082 - categorical_accuracy: 0.4398 - precision: 0.4512 - auc: 0.7063 - auc_1: 0.6921 - val_loss: 3.3835 - val_categorical_accuracy: 0.2955 - val_precision: 0.3250 - val_auc: 0.4347 - val_auc_1: 0.4480
# Epoch 36/50
# 100/100 [==============================] - 37s 369ms/step - loss: 2.6066 - categorical_accuracy: 0.4185 - precision: 0.4267 - auc: 0.6938 - auc_1: 0.6719 - val_loss: 8.7438 - val_categorical_accuracy: 0.3182 - val_precision: 0.3182 - val_auc: 0.5421 - val_auc_1: 0.5495
# Epoch 37/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.3198 - categorical_accuracy: 0.4749 - precision: 0.4771 - auc: 0.7204 - auc_1: 0.7026 - val_loss: 3.4936 - val_categorical_accuracy: 0.2045 - val_precision: 0.2105 - val_auc: 0.4740 - val_auc_1: 0.4753
# Epoch 38/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.0726 - categorical_accuracy: 0.5075 - precision: 0.5210 - auc: 0.7569 - auc_1: 0.7414 - val_loss: 3.5232 - val_categorical_accuracy: 0.3182 - val_precision: 0.3077 - val_auc: 0.4469 - val_auc_1: 0.4457
# Epoch 39/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.3626 - categorical_accuracy: 0.5025 - precision: 0.5181 - auc: 0.7515 - auc_1: 0.7371 - val_loss: 220.6939 - val_categorical_accuracy: 0.1136 - val_precision: 0.1136 - val_auc: 0.5191 - val_auc_1: 0.5201
# Epoch 40/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.1357 - categorical_accuracy: 0.5025 - precision: 0.5074 - auc: 0.7490 - auc_1: 0.7336 - val_loss: 6.2680 - val_categorical_accuracy: 0.3636 - val_precision: 0.3636 - val_auc: 0.4927 - val_auc_1: 0.4935
# Epoch 41/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.0951 - categorical_accuracy: 0.5376 - precision: 0.5492 - auc: 0.7692 - auc_1: 0.7543 - val_loss: 3.8046 - val_categorical_accuracy: 0.2500 - val_precision: 0.2619 - val_auc: 0.4662 - val_auc_1: 0.4576
# Epoch 42/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.2317 - categorical_accuracy: 0.5376 - precision: 0.5493 - auc: 0.7745 - auc_1: 0.7594 - val_loss: 45.5376 - val_categorical_accuracy: 0.1818 - val_precision: 0.1818 - val_auc: 0.5103 - val_auc_1: 0.5020
# Epoch 43/50
# 100/100 [==============================] - 37s 368ms/step - loss: 1.9318 - categorical_accuracy: 0.5476 - precision: 0.5486 - auc: 0.7851 - auc_1: 0.7745 - val_loss: 3.0213 - val_categorical_accuracy: 0.2727 - val_precision: 0.2727 - val_auc: 0.5489 - val_auc_1: 0.5330
# Epoch 44/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.1018 - categorical_accuracy: 0.5188 - precision: 0.5335 - auc: 0.7774 - auc_1: 0.7618 - val_loss: 392.1297 - val_categorical_accuracy: 0.1364 - val_precision: 0.1364 - val_auc: 0.5400 - val_auc_1: 0.5371
# Epoch 45/50
# 100/100 [==============================] - 37s 367ms/step - loss: 1.8604 - categorical_accuracy: 0.5915 - precision: 0.5992 - auc: 0.8019 - auc_1: 0.7921 - val_loss: 227.4913 - val_categorical_accuracy: 0.2727 - val_precision: 0.2727 - val_auc: 0.4868 - val_auc_1: 0.4858
# Epoch 46/50
# 100/100 [==============================] - 37s 368ms/step - loss: 1.9169 - categorical_accuracy: 0.5915 - precision: 0.5984 - auc: 0.8075 - auc_1: 0.7987 - val_loss: 46.7514 - val_categorical_accuracy: 0.3182 - val_precision: 0.3182 - val_auc: 0.5230 - val_auc_1: 0.5339
# Epoch 47/50
# 100/100 [==============================] - 37s 368ms/step - loss: 1.8839 - categorical_accuracy: 0.6040 - precision: 0.6155 - auc: 0.8183 - auc_1: 0.8107 - val_loss: 5.2538 - val_categorical_accuracy: 0.3636 - val_precision: 0.3750 - val_auc: 0.4670 - val_auc_1: 0.4779
# Epoch 48/50
# 100/100 [==============================] - 37s 368ms/step - loss: 2.0877 - categorical_accuracy: 0.5952 - precision: 0.6013 - auc: 0.8117 - auc_1: 0.8023 - val_loss: 9.4974 - val_categorical_accuracy: 0.2500 - val_precision: 0.2500 - val_auc: 0.4860 - val_auc_1: 0.4947
# Epoch 49/50
# 100/100 [==============================] - 37s 368ms/step - loss: 1.9117 - categorical_accuracy: 0.6078 - precision: 0.6155 - auc: 0.8167 - auc_1: 0.8066 - val_loss: 9.9311 - val_categorical_accuracy: 0.2500 - val_precision: 0.2439 - val_auc: 0.4782 - val_auc_1: 0.4903
# Epoch 50/50
# 100/100 [==============================] - 37s 368ms/step - loss: 1.5823 - categorical_accuracy: 0.6316 - precision: 0.6435 - auc: 0.8527 - auc_1: 0.8440 - val_loss: 5.5758 - val_categorical_accuracy: 0.2727 - val_precision: 0.2791 - val_auc: 0.4300 - val_auc_1: 0.4386

# %%
keys = list(multi_VGG_test.history.history.keys())

plt.figure(figsize=(10, 25))

plt.subplot(5, 1, 1)
plt.plot(multi_VGG_test.history.history[keys[0]], label='Training', marker='o')
plt.plot(multi_VGG_test.history.history[keys[5]], label='Validation', marker='o')
plt.title('Loss evolution')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Loss on train dataset', 'Loss on validation dataset'])

plt.subplot(5, 1, 2)
plt.plot(multi_VGG_test.history.history[keys[1]], label='Training', marker='o')
plt.plot(multi_VGG_test.history.history[keys[6]], label='Validation', marker='o')
plt.title('Accuracy evolution')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Accuracy on train dataset', 'Accuracy on validation dataset'])

plt.subplot(5, 1, 3)
plt.plot(multi_VGG_test.history.history[keys[2]], label='Training', marker='o')
plt.plot(multi_VGG_test.history.history[keys[7]], label='Validation', marker='o')
plt.title('Precision evolution')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend(['Precision on train dataset', 'Precision on validation dataset'])

plt.subplot(5, 1, 4)
plt.plot(multi_VGG_test.history.history[keys[3]], label='Training', marker='o')
plt.plot(multi_VGG_test.history.history[keys[8]], label='Validation', marker='o')
plt.title('AUC evolution')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend(['AUC on train dataset', 'AUC on validation dataset'])

plt.subplot(5, 1, 5)
plt.plot(multi_VGG_test.history.history[keys[4]], label='Training', marker='o')
plt.plot(multi_VGG_test.history.history[keys[9]], label='Validation', marker='o')
plt.title('AUC evolution')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend(['AUC with weights on train dataset', 'AUC with weights on validation dataset'])

# %%
results_from_nn_test = []

for x in X_test:
  results_from_nn_test.append(multi_VGG_test.predict(np.array([x]), verbose=0))

multi_VGG_test.evaluate(X_test, y_test, batch_size=1)

confusion_matrix_test = [[0 for _ in range(4)] for _ in range(4)]

for pred, res in zip(results_from_nn_test, y_test):
  pred = np.argmax(pred[0])
  res = np.argmax(res)
  confusion_matrix_test[pred][res] += 1

seaborn.heatmap(confusion_matrix_test, annot=True)
# Out:
# 45/45 [==============================] - 2s 46ms/step - loss: 6.1097 - categorical_accuracy: 0.3111 - precision: 0.2955 - auc: 0.5327 - auc_1: 0.5273
# <Axes: >

# %%
multi_VGG_test.load_weights('./models/accuracy/')

results_from_nn_test = []

for x in X_test:
  results_from_nn_test.append(multi_VGG_test.predict(np.array([x]), verbose=0))

multi_VGG_test.evaluate(X_test, y_test, batch_size=1)

confusion_matrix_test = [[0 for _ in range(4)] for _ in range(4)]

for pred, res in zip(results_from_nn_test, y_test):
  pred = np.argmax(pred[0])
  res = np.argmax(res)
  confusion_matrix_test[pred][res] += 1

seaborn.heatmap(confusion_matrix_test, annot=True)
# Out:
# 45/45 [==============================] - 2s 46ms/step - loss: 3.7233 - categorical_accuracy: 0.2000 - precision: 0.2143 - auc: 0.4288 - auc_1: 0.4315
# <Axes: >

# %%
multi_VGG_test.load_weights('./models/precision/')

results_from_nn_test = []

for x in X_test:
  results_from_nn_test.append(multi_VGG_test.predict(np.array([x]), verbose=0))

multi_VGG_test.evaluate(X_test, y_test, batch_size=1)

confusion_matrix_test = [[0 for _ in range(4)] for _ in range(4)]

for pred, res in zip(results_from_nn_test, y_test):
  pred = np.argmax(pred[0])
  res = np.argmax(res)
  confusion_matrix_test[pred][res] += 1

seaborn.heatmap(confusion_matrix_test, annot=True)
# Out:
# 45/45 [==============================] - 2s 46ms/step - loss: 1.6479 - categorical_accuracy: 0.2000 - precision: 0.2222 - auc: 0.5417 - auc_1: 0.5423
# <Axes: >

# %%
multi_VGG_test.load_weights('./models/auc1/')

results_from_nn_test = []

for x in X_test:
  results_from_nn_test.append(multi_VGG_test.predict(np.array([x]), verbose=0))

multi_VGG_test.evaluate(X_test, y_test, batch_size=1)

confusion_matrix_test = [[0 for _ in range(4)] for _ in range(4)]

for pred, res in zip(results_from_nn_test, y_test):
  pred = np.argmax(pred[0])
  res = np.argmax(res)
  confusion_matrix_test[pred][res] += 1

seaborn.heatmap(confusion_matrix_test, annot=True)
# Out:
# 45/45 [==============================] - 2s 46ms/step - loss: 1.6479 - categorical_accuracy: 0.2000 - precision: 0.2222 - auc: 0.5417 - auc_1: 0.5423
# <Axes: >

# %%
multi_VGG_test.load_weights('./models/auc2/')

results_from_nn_test = []

for x in X_test:
  results_from_nn_test.append(multi_VGG_test.predict(np.array([x]), verbose=0))

multi_VGG_test.evaluate(X_test, y_test, batch_size=1)

confusion_matrix_test = [[0 for _ in range(4)] for _ in range(4)]

for pred, res in zip(results_from_nn_test, y_test):
  pred = np.argmax(pred[0])
  res = np.argmax(res)
  confusion_matrix_test[pred][res] += 1

seaborn.heatmap(confusion_matrix_test, annot=True)
# Out:
# 45/45 [==============================] - 2s 46ms/step - loss: 1.6479 - categorical_accuracy: 0.2000 - precision: 0.2222 - auc: 0.5417 - auc_1: 0.5423
# <Axes: >

# %%
multi_VGG_test.load_weights('.models/models/loss/')

results_from_nn_test = []

for x in X_test:
  results_from_nn_test.append(multi_VGG_test.predict(np.array([x]), verbose=0))

multi_VGG_test.evaluate(X_test, y_test, batch_size=1)

confusion_matrix_test = [[0 for _ in range(4)] for _ in range(4)]

for pred, res in zip(results_from_nn_test, y_test):
  pred = np.argmax(pred[0])
  res = np.argmax(res)
  confusion_matrix_test[pred][res] += 1

seaborn.heatmap(confusion_matrix_test, annot=True)
# Out:
# 45/45 [==============================] - 2s 46ms/step - loss: 1.6479 - categorical_accuracy: 0.2000 - precision: 0.2222 - auc: 0.5417 - auc_1: 0.5423
# <Axes: >
